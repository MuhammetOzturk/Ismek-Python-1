# %% [markdown]
# # Kurulumlar
# Python , anaconda jupyter notebook

# %% [markdown]
# ### Neden Programlama Öğrenmek İsteyeyim?
# ???
# Hayatımızda ne gibi kolaylıklar sağlar.

# %% [markdown]
# ### Programlama Dili Nedir
# İnsanlar geçmişten günümüze her zaman çeşitli hesaplama aletleriyle hesap yapma ihtiyacı duymuştur. Bu ihtiyaç ilk çağlardan itibaren kullanılan abaküsten başlayıp günümüze kadar gelişmiş süper bilgisayarlara evrilmiştir. Bilgisayalarda hesaplama işlemleri yapabilmek için programlama dilleri ortaya çıkmıştır.
#
# Programlama dili, bilgisayar sistemlerine belirli görevleri gerçekleştirmek için talimatlar vermek için kullanılan bir yapılardır. Bu diller, insanların anlayabileceği bir dilde yazılmış komutları, bilgisayarların anlayabileceği bir dilde çeviren araçlardır. Programlama dilleri, genellikle yüksek seviyeli ve düşük seviyeli diller olarak iki kategoride bulunur.
#
# 1. **Yüksek Seviyeli Diller:** Bu diller, insanların daha rahat anlayabileceği ve yazabileceği düzeyde tasarlanmıştır. Bu tür diller, genellikle daha fazla soyutlama sağlar ve karmaşıklığı azaltarak programcıların kod yazma sürecini kolaylaştırır. Örnekler arasında Python, Java, C#, JavaScript ve Ruby bulunur.
#
# 2. **Düşük Seviyeli Diller:** Bu diller, daha çok bilgisayar donanımı ile doğrudan iletişim kurmak için tasarlanmıştır ve genellikle daha fazla kontrol sağlar. Assembly dili ve makine dili, düşük seviyeli dillere örnektir. Bu diller, genellikle yüksek seviyeli dillerden daha hızlı çalışabilir, ancak genellikle daha karmaşık ve anlaşılması zordur.
#
# Programlama dilleri genellikle belirli programlama paradigmasına (örneğin, nesne yönelimli programlama, işlevsel programlama) göre de sınıflandırılabilirler. Her dilin kendine özgü bir sentaksı (dil kuralları) ve semantiği (dil anlamı) vardır.
#
# Herhangi bir programlama dilinin kullanımı, belirli bir görevin gereksinimlerine ve programcının tercihlerine bağlı olarak değişebilir. Programlama dilleri, yazılım geliştirmek, veri analizi yapmak, yapay zeka uygulaması oluşturmak ve daha birçok uygulama alanında kullanılabilir.

# %% [markdown]
# ### Python Veri Türleri
# Number (Sayılar)
# String (Karakter)
# List (Listeler)
# Tuple(Demetler)
# Dictionary(Sözlükler)
# Sets(Kümeler)
#
# Bu veri türü de kendi aralarında 4’e ayrılır bunlar ;
#
# Integer
# Float
# Long Integer
# Complex
#
# **Integer (Tamsayılar ):** Matematikte gördüğümüz pozitif ve negatif sayıların tamamına denir ve Python da bir temel sayısal veri türüdür. Örnek verecek olursak; 5, -10, 423365 vb.
#
# ```python
# sayi = 10
# ```
#
# **Float (Ondalıklı sayılar):** Matematikte gördüğümüz kesirli negatif ve pozitif sayıların tamamına denir. Integer gibi Python da bir sayısal temel veri türüdür. Örnek verecek olursak; 5.25, -4.10, 456.40 vb.
#
# ```python
# pi = 3.14
# ```
#
# **Long Integer (Uzun  tamsayılar):** Uzun tamsayıları  ifade eden veri türüdür. Integer veri  türleri çok büyük rakamlar için yetersiz kalacaktır bu tür durumlarda Long Integer kullanılır;5533514554585L, 7L ,Kriptografi de kullanimi yaygindir.
# ```python
# key = 67889090909999998787878787 L
# ```
# **Complex (Karmaşık sayılar):** Karmaşık sayılar gömülü sistemlerde sıkça kullanılan gerçek ve sanal olmak üzere iki kısımdan oluşan sayı tipidir. Şu şekilde gösterilirler ; 5+12j, 4-3j
#
# ```python
# x = 1 + 2j
# y = 2j
# z = x + y
# # z = 1+ 4j
# ```
#
# **String:** Python da metin türündeki veri türüdür yani karakter dizileridir.
# ```python
# isim = "Muhammet"
# ```
# **Tuple:** Farklı veri türlerinin bir araya gelerek oluşturduğu veri türleridir; yani bir Tuple içinde tamsayı, ondalık sayı, metin ve hatta bir Tuple içinde başka bir Tuple olabilir.
# ```python
# x=1,2,3
# y="merhaba dunya",
# z="merhaba","dunya","1","2"
# t=("merhaba","dunya","1","2")
# ```
# **Tuple ve string veri turleri degistirilemez veri tipleridir.**
#
# **List :** Listeler de Tuple gibi farklı veri türlerinin bir araya gelmesiyle oluşmuştur. Listelerin içinde tamsayı ,ondalık sayı, string, tuple ve listelerden oluşur. Tuple veri türünden farkı ise siz bu veri türüne eleman; ekleme ,çıkarma ve değiştirme işlemlerini yapabilirsiniz, ileri ki konularda detaylı bir şekilde metotları ile birlikte anlatılacaktır. Kullanım şekli şu şekildedir.
# ```python
# x = [1,2,3]
# y = [12,"deneme", ["test", "test2"]]
# ```
# Dictionary: Sözlükler de Tuple ve List veri türleri gibi farklı veri türleri bulunur fakat sözlükler biraz  farklıdır. Sözlükler süslü parantezler ile ifade edilir ve  iki kısımdan oluşur; keys(anahtar) ve value(değer),  value kısmı bütün veri türünü içerebilir fakat keys kısmı sadece string ve int tipinde olabilir. Sözlüklerde değiştirilebilir veri türü olup ekleme,çıkarma vb. işlemler yapılabilir ileri ki konularda detaylı bir şekilde anlatılacaktır.
# ```python
# Plaka_numaraları={
#     "01" : "Adana",
#     "02" : "Adıyaman",
#     "03" : "Afyonkarahisar",
#     "04" : "Ağrı",
#     "05" : "Amasya",
#     "06" : "Ankara",
#     "07" : "Antalya"
# }
#
# Plaka_numaraları["25"] = "Erzurum"
# ```
#
# ### Etkileşimli Kabuk Kullanımı
# "**>>>** " işareti Python’ın bizden komut almaya hazır
# olduğunu gösteriyor.Etkileşimli modda satır satır çalışılır.
#
# **>>>** "merhaba"
# merhaba
#
# **>>>** 'merhaba'
# merhaba
#
# Yukarıdaki ifadeler karakter dizileri olarak adlandırılır.Bu ifadelerin tip tanımlamalarını **type** fonksiyonu ile öğrenebiliriz.
#
# **>>>** type("merhaaba")
# str
#
# Bir değişkenin veya bir ifadenin sahip olduğu fonksiyonları **dir** fonksiyonu ile öğrenebiliriz.
#
#
# **>>>** dir(str)
# ...
#  'rpartition',
#  'rsplit',
#  'rstrip',
#  'split',
#  'splitlines',
#  'startswith',
#  'strip',
#  'swapcase' ,
# ...
#
# **help** fonksiyonu ile degisken hakkinda bilgi aliriz.
# ```python
# help(str)
# ```
#
# **Basit Matematik İşlemler ve Operatörleri**
# ```python
# 3+5
#
# 5-3
#
# 5*3
#
# 6/4
#
# 6//4 tam bolme
#
# 6%4 kalan
#
# 2**3 us alma
#
# x=2; y=-2 z=x*y isaret degistirme
# ```
#
# **Islem Onceligi Sirasi**
# Parantez içi her zaman önce yapılır.
# Üst alma
# Çarpma ve Bölme
# Toplama ve Çıkarma
# İşlemler soldan sağa doğru yapılır.
#
# ```python
#  (5 + 3) * 2 * 2**3 // 3
#
# x = 10
# y = 11
# z = x * y
# ```
#
# ---
# # <center>Soru</center>
# 1 - Diyelim ki aylık yol masrafımızı hesaplayan bir program yazmak istiyoruz. Elimizdeki verilerin
# şunlar olduğunu varsayalım:
#  1. Cumartesi-Pazar günleri çalışmıyoruz.
#  2. Dolayısıyla ayda 22 gün çalışıyoruz.
#  3. Evden işe gitmek için kullandığımız vasıtanın ücreti 15 TL
#  4. İşten eve dönmek için kullandığımız vasıtanın ücreti 12 TL
# Aylık yol masrafımızı hesaplayabilmek için gidiş ve dönüş ücretlerini toplayıp, bunları
# çalıştığımız gün sayısıyla çarpmamız yeterli olacaktır. Elimizdeki bu bilgilere göre aylık yol
# masrafımızı hesaplamak için şöyle bir formül üretebiliriz:
#
# masraf = gün sayısı x (gidiş ücreti + dönüş ücreti)
#
# 2 - Yillik masrafini hesaplayiniz?
#
# masraf = gün sayısı x (gidiş ücreti + dönüş ücreti) * 12
#
# 3 - Capi 3 olarak verilen dairenin alanini hesaplayiniz?
# pi = 3.14
# r = 3/2
# alan = pi\*r\*r
#
# veya
#
# alan = pi \* (r ** 2)

# %% [markdown]
# **Python Degisken Olusturma**
#
# 1. Değişken ismi içinde **:'”,<>/?|\()!@#$%^&*~-+** karakterleri kullanılamaz.Değişken ismi sadece sayı,harf  ve “_” karakteri içerebilir.
# 2. Değişken isimleri bir sayı  ve aritmetik operatör ile başlayamaz .
#    4satır="Merhaba"
#    +değişkeni ="Toplama işlemi yapar"
# 3. Değişken ismi kelimelerden oluşuyorsa aralarında boşluk olamaz.
#    birinci metin ="Hello World"
# 4. Python da tanımlı anahtar kelimeler değişken ismi olarak kullanılamaz .

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %% [markdown]
# ---

# %% [markdown]
# **String**
#
# Her programlama dilinde olduğu gibi Python programlama dilinde de karakter dizileri yani string  değişken tipi büyük önem arz eder. Çünkü tanımlayacağınız birçok değişken string ifadeler içerir. Üstelik string değişken tipleri üzerinden yürütebileceğiniz birçok Python fonksiyonu mevcuttur. Bir string yani str veri tipinde değerler " (çift tırnak), ' (tek tırnak), """ (üç tırnak) ifadeleri arasında gösterilir.
#
# ```python
# x = "test"
# y = 'test'
# z = """test"""
# ```
#
# Bu örnekte gördüğünüz her üç değişken de birebir aynıdır. Siz istediğiniz kullanımı tercih edebilirsiniz. Fakat bir kullanım belirledikten sonra değerinizin içinde aynı işareti kullanamazsınız çünkü Python değerin bitiş yerini orası belirler.
#
# ```python
# metin = 'Ali'nin arabasi var.' #yanlis
# metin = "Yunus'un arabası var" #dogru
#
# #DOĞRU
# isim = 'Kalem'
#
# #DOĞRU
# isim = "Kagit"
#
# #YANLIŞ
# isim = "Klavye'
#
# #YANLIŞ
# isim = "Kamera"""
# ```
#
#
# Bir string  veri tipinde değişken oluşturmuşsanız aynı zamanda bir dizi oluşturmuşsunuz demektir. Çünkü ders başlığında da yazdığımız gibi bir string değişken karakter dizisi şeklinde veri tipidir.
#
# ```python
# sehir = "Istanbul"
# print(sehir[0])    #I
# print(sehir[1])    #s
# print(sehir[2])    #t
# print(sehir[-1])   #l
# print(sehir[-2])   #u
# print(sehir[0:4])  #Ista
# ```
#
# Elinizdeki string değişkenin kaç karakterden oluştuğunu öğrenmek için len() fonksiyonunu kullanabilirsiniz.
#
# ```python
# sehir = "Istanbul"
# len(sehir)
# 8
# ```
#
# Bir metinin başındaki ve sonundaki boşlukları temizlemek için strip() fonksiyonunu kullanabilirsiniz.
#
# ```python
# a = " Suyu israf etmeyin! "
#
# print(a.strip()) # "Suyu israf etmeyin!"
# ```
#
# Elinizdeki metini tamamen büyük harflere çevirmek istiyorsanız upper() fonksiyonunu kullanabilirsiniz.
#
# ```python
# a = "Ağaçlar ciğerlerimizdir"
#
# print(a.upper()) # AĞAÇLAR CIĞERLERIMIZDIR
# ```
#
# Elinizdeki metini tamamen küçük harflere çevirmek istiyorsanız lower() fonksiyonunu kullanabilirsiniz.
#
# ```python
# a = "AĞAÇLAR CİĞERLERİMİZDİR"
# print(a.lower()) # ağaçlar ciğerlerimizdir
# ```
#
# Metindeki bir karakter veya bir kelime grubunu başka bir karakter veya metin grubuyla değiştirmek istediğinizde replace() fonksiyonunu kullanabilirsiniz.
#
# ```python
# a = "Muz tatlı bir meyvedir"
#
# print(a.replace("Muz", "Çilek")) #Çilek tatlı bir meyvedir
# ```
#
# Elinizdeki belirlediğiniz bir karakterden bölerek diziye atayabilirsiniz. Aşağıdaki örnekte örnek kullanımını görebilirsiniz.
#
# ```python
# a = "Kayseri,Nevşehir,Kırşehir İç Anadolu bölgesindedir"
#
# print(a.split(",")) # ['Kayseri', 'Nevşehir', 'Kırşehir İç Anadolu bölgesindedir']
# ```
#
# Bir metin editöründe nasıl karakter veya metin arayabiliyorsanız Python programlama diliyle de string değişkeniniz içinde in ve not in terimleriyle herhangi bir karakter veya metin arayabilirsiniz.
#
# ```python
# txt = "En sevdiğim hava yağmurlu havadır"
#
# x = "mur" in txt
#
# print(x)            # True
# ```
#
# Bazı durumlarda elinizde bulunan string değerleri birbirleriyle birleştirmek ve yan yana eklemek isteyebilirsiniz. Bunun için matematiksel ifade olan + işareti kullanılır. Örneklerini aşağıda görebilirsiniz.
#
# ```python
# a = "Bir"
# b = " "
# c = "Blog"
#
# print(a+b+c)
# print(c + "yazmak düzeldir")
# ```
#
# Bir kelimeyi veya karakteri istediğimiz adette yazmak için matematiksel ifade olan * işareti kullanılır. Örneklerini aşağıda görebilirsiniz.
#
# ```python
# a = "elma"
#
# print(a*3)        # elmaelmaelma
# ```
#
# Bir string değişken belirlerken hangi işaretle başladıysanız o işaretle bitirmelisiniz . Fakat kaçış karakteri (\) kullanılarak bu durumun üstesinden gelinebilir.

# %% [markdown]
# # Listeler
#
# Python koleksiyonlar (diziler) altında yer alan liste (list) veri tipimiz sıralanabilen , değiştirilebilen , indekslenebilen  ve çoğul elemana izin veren bir veri tipidir. Köşeli parantezlerle [ ] oluşturulur.
# liste = []
# Köşeli parantezlere oluşturulan listeler, en başta elemanlarla birlikte de oluşturulabilirler.
# liste = ["Ankara","İstanbul","Kayseri"]
# Aynı zamanda bir liste list() fonksiyonu ile de oluşturulabilir ve constructor yöntemiyle başlangıçta elemanları ayarlanabilir.
# liste = list()
#
# liste = list(("Ankara","İstanbul","Kayseri"))
# Oluşturduğumuz liste değişkenlerinin tipini kontrol edelim.
# print(type(liste)) # <class 'list'>
#
# ```python
# liste = ["Sal","Vapur","Feribot","Korvet","Fırkateyn"]
#
# print(liste[0])    # Sal
# print(liste[1])    # Vapur
# print(liste[2])    # Feribot
# print(liste[-2])    # Korvet
# print(liste[-1])    # Fırkateyn
# ```
#
# Listeden yeni liste olusturma
#
# ```python
# liste = ["a","b","c","d","e","f","g"]
#
# yeniliste = liste[2:5]
#
# print(yeniliste)    #["c","d","e"]
# ```
#
# Eleman sayisini ogrenmek.
#
# ```python
# liste = ["a","b","c","d"]
#
# print(len(liste))    #4
# ```
#
# Eleman  sayisini sorgulama
#
# ```python
# liste = ["a","b","c","c","d","c"]
#
# sayac = liste.count("c")
#
# print(sayac)    #3
# ```
#
# Liste eleamnini degistirme
#
# ```python
# meyveler = ["kivi","çilek","muz","pırasa"]
#
# meyveler[3] = "armut"
#
# print(meyveler)    # ["kivi","çilek","muz","armut"]
# ```
#
# Listeye yeni eleman ekleme
#
# ```python
# meyveler = ["kivi","çilek"]
#
# meyveler.append("muz")
#
# print(meyveler)    # ["kivi","çilek","muz"]
# ```
#
# Eleman cikarma
#
# ```python
# meyveler = ["kivi","çilek","muz","armut"]
#
# meyveler.pop()
#
# print(meyveler)    # ["kivi","çilek","muz"]
#
# meyveler = ["kivi","çilek","muz","armut"]
#
# meyveler.remove("çilek")
#
# print(meyveler) # ["kivi","muz","armut"]
#
# meyveler = ["kivi","çilek","muz","armut"]
#
# del meyveler[0]
#
# print(meyveler) # ["çilek","muz","armut"]
# ```
#
# Liste kopyalama.
#
# ```python
# liste = ["a","b","c","d"]
#
# yeniliste = liste.copy()
#
# print(yeniliste) # ["a","b","c","d"]
# ```
#
# Iki listeyi birlestirme
#
# ```python
# liste1 = ["A","B","C"] liste2 = ["D","E"]
#
# liste3 = liste1 + liste2
#
# print(liste3) # ["A","B","C","D","E"]
#
# liste1 = ["A","B","C"] ; liste2 = ["D","E"]
#
# liste1.extend(liste2)
#
# print(liste1) # ["A","B","C","D","E"]
# ```
#
# Liste elemanlarini siralama.
#
# ```python
# liste = [14,36,2,95,43,0,66]
#
# liste.sort()
#
# print(liste) # [0, 2, 14, 36, 43, 66, 95]
# ```
#
# Listedeki elemanin sirasini bulmak.
#
# ```python
# liste = [14,36,2,95,43,0,66]
#
# print(liste.index(95)) # 3
# ```
#
# Listede elemanin varligini kontrol etmek.
#
# ```python
# liste = ["A","B","C","D","E"]
# 'A' in liste
# ```

# %% [markdown]
# ### Demetler
# Python koleksiyonlar (diziler) altında yer alan demet (tuple) veri tipimiz sıralanabilen , indekslenebilen, çoğul elemana izin veren ama değiştirilemeyen bir veri tipidir. Yuvarlak parantezlerle ( ) oluşturulur.
#
# ```python
# demet = () #bos demet
# demet = ("elma","armut","çilek")
# ```
# Elemanlara ersim
#
# ```python
# demet = ("Ceviz","Fındık","Fıstık","Leblebi")
#
# print(demet[0]) # Ceviz
# print(demet[1]) # Fındık
# print(demet[-2]) # Fıstık
# print(demet[-1]) # Leblebi
# ```
#
# Demet'ten yeni demet olusturma
#
# ```python
# demet = ("a","b","c","d","e","f","g")
#
# yenidemet = demet[2:5]
#
# print(yenidemet) #("c","d","e")
# ```
# Ornekler:
#
# ```python
# demet = ("a","b","c","d")
#
# print(len(demet)) #4
#
# demet = ("a","b","c","c","d","c")
#
# sayac = demet.count("c")
#
# print(sayac) #3
#
# #tip donusumu  ve eleman degisimi ornegi
# x = ("kivi","çilek","muz","karpuz")
# y = list(x)
#
# y[1] = "avakado"
# x = tuple(y)
#
# print(x) # ("kivi","çilek","muz","karpuz")
#
# #index bulma
#
# demet = (14,36,2,95,43,0,66)
#
# print(demet.index(95)) # 3
# ```

# %% [markdown]
# ### Kumeler
# Python koleksiyonlar (diziler) altında yer alan küme (set) veri tipimiz sıralanamayan , değiştirilemeyen, indekslenemeyen ve çoğul elemana izin vermeyen bir veri tipidir. Süslü parantezlerle { } oluşturulur.
#
# ```python
# kume = {"elma","armut","çilek"}
# kume = set() #bos kume
#
# kume = set(("Ankara","İstanbul","Kayseri"))
#
# kume = {"a","b","c","d"}
#
# print(len(kume)) #4
#
# kume = {"a","b","c","d"}
#
# print("b" in kume) # True
# print("f" in kume) # False
#
# kume = {"a","b","c"}
#
# #eleman ekleme
# kume.add("g")
#
# print(kume) # {"b","c","g","a"}
#
# #coklu eleman ekleme
# kume = {"a","b","c"}
#
# kume.update(["x","y","z"])
#
# print(kume) # {'y', 'c', 'b', 'x', 'z', 'a'}
#
# kume = {"a","b","c"}
# liste = ["x","y","z"]
# demet = (1,2,3)
#
# kume.update(liste)
# kume.update(demet)
#
# print(kume) # {1, 2, 3, 'y', 'a', 'x', 'c', 'b', 'z'}
#
# #eleman cikarma
#
# kume = {"a","b","c","d"}
#
# kume.remove("b")
#
# print(kume) # {'a', 'c', 'd'}
#
# #kume kopyalama
# kume = {"a","b","c","d"}
#
# yenikume = kume.copy()
#
# print(yenikume) # {'a', 'd', 'b', 'c'}
#
# #iki kumeyi birlestirme
# kume1 = {"A","B","C"}
# kume2 = {"D","E"}
#
# kume3 = kume1.union(kume2)
#
# print(kume3) # {'E', 'C', 'D', 'B', 'A'}
#
# kume1 = {"A","B","C"}
# kume2 = {"D","E"}
#
# kume1.update(kume2)
#
# print(kume1) # {'D', 'C', 'E', 'B', 'A'}
#
# #kesisim alma
#
#  kume1 = {"A","B","C"}
#  kume2 = {"A","D"}
#  kume3 = {"F","G"}
#
# kume1 = {"A","B","C"}
# kume2 = {"A","D"}
#
# kesisim= kume1.intersection(kume2)
#
# print(kesisim) # {"A"}
#
# #kume farkini alama
# kume1 = {"A","D","G"}
# kume2 = {"A","B","C","D"}
#
# # kume1 in kume2 den farkı
# fark = kume1.difference(kume2)
#
# print(fark) # {"G"}
# ```

# %% [markdown]
# ### Sozlukler
#
# Python koleksiyonlar (diziler) altında yer alan sözlük (dict) veri tipimiz değiştirilebilen , indekslenebilen, çoğul elemana izin veren ama sıralanamayan  bir veri tipidir. Süslü parantezlerle { } oluşturulur.
#
# ```python
# sozluk = {}
#
# sozluk = {
#          "marka" : "BMW",
#          "model" : "i8",
#          "yil"   : 2019
#          }
#
# sozluk = dict()
#
# sozluk = dict(sehir = "Ankara", plaka = 6)
#
# sozluk = {
#          "ulke" : "Türkiye",
#          "sehir" : "Ankara",
#          "ilce"   : "Yenimahalle"
#          }
#
#
#
# print(len(sozluk))    #3
#
# #yeni eleman ekleme
# sozluk = {
#          "marka" : "BMW",
#          "model" : "i8",
#          }
#
# sozluk["yil"] = 2019
#
# print(sozluk)       # {'yil': 2019, 'marka': 'BMW', 'model': 'i8'}
#
# #deger degistirme
# sozluk['marka'] = 'Audi'
#
# print(sozluk)
# ```
# ### Ornekler
#
# ### 1. Sözlük Oluşturma:
#
# ```python
# sozluk = {"anahtar1": "değer1", "anahtar2": "değer2", "anahtar3": "değer3"}
# ```
#
# ### 2. Değer Ekleme veya Güncelleme:
#
# ```python
# sozluk["yeni_anahtar"] = "yeni_deger"  # Yeni bir anahtar-değer çifti ekler veya var olanı günceller
# ```
#
# ### 3. Değer Okuma:
#
# ```python
# deger = sozluk["anahtar1"]  # Belirtilen anahtara karşılık gelen değeri alır
# ```
#
# ### 4. Anahtarları Listeleme:
#
# ```python
# anahtarlar = list(sozluk.keys())  # Sözlükteki tüm anahtarları bir liste olarak alır
# ```
#
# ### 5. Değerleri Listeleme:
#
# ```python
# degerler = list(sozluk.values())  # Sözlükteki tüm değerleri bir liste olarak alır
# ```
#
# ### 6. Anahtar-Değer Çiftlerini Listeleme:
#
# ```python
# ciftler = list(sozluk.items())  # Sözlükteki tüm anahtar-değer çiftlerini bir liste olarak alır
# ```
#
# ### 7. Değer Silme:
#
# ```python
# del sozluk["anahtar1"]  # Belirtilen anahtar-değer çiftini siler
# ```
#
# ### 8. Değer Okuma (get metodu):
#
# ```python
# deger = sozluk.get("anahtar1", default_deger)  # Anahtara karşılık gelen değeri alır, eğer anahtar yoksa default değeri döndürür
# ```
#
# ### 9. Sözlük Temizleme:
#
# ```python
# sozluk.clear()  # Sözlüğü temizler, tüm anahtar-değer çiftlerini siler
# ```
#
# ### 10. Sözlük Uzunluğu:
#
# ```python
# uzunluk = len(sozluk)  # Sözlükteki anahtar-değer çiftlerinin sayısını verir
# ```
#
# Bu, Python'da sözlüklerle çalışırken kullanılan bazı temel fonksiyonlar ve yöntemlerdir. Sözlükler, veri manipülasyonu ve organizasyonunda çok güçlüdür ve genellikle programlarda yapılandırılmış veri depolamak için kullanılır.

# %% [markdown]
# **Print Fonksiyonu**
# Python'da `print()` fonksiyonu, ekrana çıktı vermeyi sağlayan temel bir fonksiyondur. Bu fonksiyon, bir veya daha fazla değeri alır ve bu değerleri standart çıktıya (genellikle terminal veya komut istemcisine) yazdırır.
#
# 1. **Tek Değer Yazdırma:**
#    ```python
#    print("Merhaba, Dünya!")
#    ```
#    Bu örnek, ekrana "Merhaba, Dünya!" metnini yazdırır.
#
# 2. **Birden Fazla Değer Yazdırma:**
#    ```python
#    ad = "John"
#    yas = 25
#    print("Ad:", ad, "Yaş:", yas)
#    ```
#    Birden fazla değeri virgülle ayırarak `print()` fonksiyonuna iletebilirsiniz. Bu durumda, her bir değer arasına bir boşluk eklenir.
#
# 3. **Özel Ayarlarla Yazdırma:**
#    ```python
#    ad = "Jane"
#    yas = 30
#    print("Ad: {}, Yaş: {}".format(ad, yas))
#    ```
#    `format()` metodu kullanılarak değerler yerine geçen süslü parantezler `{}` içine yerleştirilebilir. Bu, metin içinde değişkenlerin değerlerini yerleştirmenin esnek bir yolunu sağlar.
#
# 4. **Farklı Veri Tiplerini Yazdırma:**
#    ```python
#    sayi = 42
#    kesirli_sayi = 3.14
#    print("Tam Sayı:", sayi, "Kesirli Sayı:", kesirli_sayi)
#    ```
#    `print()` fonksiyonu, farklı veri tiplerini bir arada kullanmanıza izin verir. Otomatik olarak uygun biçimlendirmeyi gerçekleştirir.
#
# 5. **End Parametresi Kullanma:**
#    ```python
#    print("Satır Sonu", end="")
#    print("Devam Ediyor")
#    ```
#    `end` parametresi, `print()` fonksiyonunun varsayılan olarak eklediği satır sonu karakterinin yerine geçer. Yukarıdaki örnekte, ikinci `print()` ifadesi, satır sonu karakteri olmadan önce devam eder.
#
# Bu örnekler, `print()` fonksiyonunun temel kullanımlarını göstermektedir. Python'da `print()` fonksiyonuyla ilgili daha fazla detay ve özellik bulunmaktadır, ancak bu temel bilgiler genellikle günlük kullanım için yeterlidir.

# %% [markdown]
# **Input Fonksiyonu**
# Python'daki `input()` fonksiyonu, kullanıcıdan klavye aracılığıyla bir giriş almak için kullanılır. Bu fonksiyon, programın çalışması sırasında kullanıcının bir şeyler girmesine izin verir ve girilen değeri bir dize olarak döndürür.
#
# 1. **Temel Kullanım:**
#    ```python
#    kullanici_girisi = input("Lütfen bir değer girin: ")
#    ```
#    Yukarıdaki örnekte, kullanıcıdan bir değer girmesi istenir ve bu değer `kullanici_girisi` adlı değişkene atanır. `input()` fonksiyonu, ekrana verilen metni gösterir ve kullanıcının giriş yapmasını bekler.
#
# 2. **Girilen Değeri Kullanma:**
#    ```python
#    isim = input("Adınızı girin: ")
#    print("Merhaba, " + isim + "!")
#    ```
#    Kullanıcının girdiği değeri alarak, program içinde kullanabilirsiniz. Bu örnekte, kullanıcının girdiği ismi kullanarak kişiye selam verilir.
#
# 3. **Sayı Girişi ve Dönüşüm:**
#    ```python
#    yas = input("Yaşınızı girin: ")
#    yas = int(yas)  # Girilen değeri tam sayıya dönüştürme
#    print("İki yıl sonra yaşınız:", yas + 2)
#    ```
#    `input()` fonksiyonu her zaman bir dize döndürür. Eğer kullanıcının girdiği değeri sayı olarak kullanmak istiyorsanız, `int()` veya `float()` gibi tür dönüşüm fonksiyonlarını kullanarak girişi uygun veri tipine çevirebilirsiniz.
#
# 4. **Birden Çok Değer Almak:**
#    ```python
#    ad, soyad = input("Adınızı ve soyadınızı girin (aralarına boşluk bırakarak): ").split()
#    print("Merhaba, {} {}!".format(ad, soyad))
#    ```
#    Kullanıcıdan birden çok değer almak için, `input()` fonksiyonuyla alınan değerleri `split()` fonksiyonu yardımıyla ayırabilirsiniz.
#
# `input()` fonksiyonu genellikle interaktif programlar veya basit kullanıcı etkileşimi gerektiren durumlarda kullanılır. Ancak, kullanıcı girişini alırken dikkatli olunmalı ve girişi güvenli bir şekilde işlemek için uygun önlemler alınmalıdır. Örneğin, kullanıcıdan alınan sayısal girişin geçerli bir sayı olup olmadığını kontrol etmek önemlidir.

# %% [markdown]
# **Yorum Satiri Kullanimi**
# Python'da yorum satırları, kodun anlaşılması ve belgelendirilmesi için kullanılan açıklamalardır. Yorumlar, Python yorumlayıcısı tarafından görmezden gelinir ve sadece insanlar tarafından okunur. Python'da iki tür yorum satırı vardır:
#
# ### 1. Tek Satırlık Yorumlar:
#
# Tek satırlık yorumlar için `#` karakteri kullanılır. Bu karakterden sonrasındaki her şey o satır boyunca yorum olarak kabul edilir.
#
# ```python
# # Bu bir tek satırlık yorum örneğidir.
# print("Merhaba, Dünya")  # Bu da bir yorumdur
# ```
#
# ### 2. Çok Satırlı Yorumlar:
#
# Çok satırlı yorumlar için üç tırnak (`'''` veya `"""`) kullanılır. Bu tırnakların arasına yazılan her şey yorum olarak kabul edilir.
#
# ```python
# '''
# Bu
# bir
# çok
# satırlı
# yorum
# örneğidir.
# '''
# print("Merhaba, Dünya")
# ```
#
# veya
#
# ```python
# """
# Bu
# da
# bir
# çok
# satırlı
# yorum
# örneğidir.
# """
# print("Merhaba, Dünya")
# ```
#
# Çok satırlı yorumlar genellikle modül veya fonksiyon başında, kodun başında veya önemli blokların başında belgelerle ilgili bilgileri içermek için kullanılır. Python'da docstring olarak adlandırılan bu çok satırlı yorumlar, modül, sınıf veya fonksiyonun belgelerini otomatik olarak oluşturmak için kullanılabilir.
#
# Örnek bir fonksiyon docstring'i:
#
# ```python
# def topla(x, y):
#     """
#     Bu fonksiyon, iki sayıyı toplar.
#
#     Parameters:
#     x (int): Toplanacak sayı
#     y (int): Toplanacak diğer sayı
#
#     Returns:
#     int: Toplam değeri
#     """
#     return x + y
# ```
#
# Yorumlar, kodunuzu daha okunabilir ve anlaşılır kılmak için önemli bir araçtır. İyi belgelenmiş kod, hem kendi yazdığınız kodu daha sonra anlamanıza yardımcı olur hem de başkalarının kodunuzu anlamasını kolaylaştırır.

# %% [markdown]
# #### Print Fonksiyonu soruları:
#
# 1. Soru: `print` fonksiyonu nasıl kullanılır?
#
# 2. Soru: Birden fazla değeri aynı satırda yazdırmak için `print` fonksiyonunda nasıl bir yöntem kullanılır?
#
# 3. Soru: `print` fonksiyonunun varsayılan ayraç değeri nedir?
#
# 4. Soru: `print` fonksiyonu ile farklı türlerdeki verileri nasıl bir arada yazdırabilirsiniz?
#
# 5. Soru: `print` fonksiyonu içindeki `end` parametresi ne işe yarar?
#
# 6. Soru: Bir metni tersten nasıl yazdırabilirsiniz? (Hint: `print` fonksiyonu içinde birkaç argüman kullanımı)
#
# 7. Soru: `print` fonksiyonunu kullanarak bir değişkenin değerini ekrana yazdırmak için hangi yöntemi kullanabilirsiniz?
#
# 8. Soru: `print` fonksiyonuyla ekrana sayıları belirli bir formatla yazdırmak için hangi yöntem kullanılabilir?
#
# 9. Soru: Bir satırı boş bırakmadan iki `print` fonksiyonu kullanarak nasıl bir çıktı elde edebilirsiniz?
#
# 10. Soru: Bir liste veya tuple içindeki öğeleri sırasıyla yazdırmak için `print` fonksiyonu içinde nasıl bir ifade kullanabilirsiniz?
#
# #### Veri Türleri Soruları:
# 1. Number: Bir sayıyı iki ile çarpan Python ifadesi nedir?
# 2. String: Bir metni tersten yazan Python kodu nedir?
# 3. List: Bir liste içindeki elemanları tersine çeviren Python kodunu yazın.
# 4. Tuple: Bir demeti oluşturan ve içinde "apple" ve "orange" olan bir Python ifadesi nedir?
# 5. Dictionary: Bir sözlükteki belirli bir anahtarın karşılık gelen değerini güncelleyen Python kodu nedir?
# 6. Sets: İki kümenin birleşimini bulan Python kodunu yazın.
# 7. Number: Bir sayının karesini hesaplayan Python ifadesi nedir?
# 8. String: Bir metinde belirli bir karakterin kaç kez geçtiğini sayan Python kodu nedir?
# 9. List: Bir liste içinde belirli bir elemanın kaç kez geçtiğini sayan Python kodunu yazın.
# 10. Tuple: Bir demette belirli bir değerin kaç kez geçtiğini sayan Python kodu nedir?
# 11. Dictionary: Bir sözlükte belirli bir anahtarın var olup olmadığını kontrol eden Python kodunu yazın.
# 12. Sets: İki kümenin farkını bulan Python kodu nedir?
# 13. Number: İki sayının toplamını bulan Python ifadesi nedir?
# 14. String: Bir metni başka bir metinle birleştiren Python kodunu yazın.
# 15. List: Bir listeden belirli bir elemanı kaldıran Python kodu nedir?
# 16. Tuple: İki demeti birleştiren Python ifadesi nedir?
# 17. Dictionary: Bir sözlükten belirli bir anahtarı ve karşılık gelen değeri kaldıran Python kodu nedir?
# 18. Sets: İki kümenin kesişimini bulan Python kodu nedir?
# 19. Number: Bir sayının karekökünü bulan Python ifadesi nedir?
# 20. String: Bir metni belirli bir karaktere göre ayıran Python kodunu yazın.
# 21. List: Bir liste içinde belirli bir elemanın indeksini bulan Python kodu nedir?
# 22. Tuple: Bir demeti belirli bir değere göre filtreleyen Python kodu nedir?
# 23. Dictionary: Bir sözlükteki tüm anahtarları listeleyen Python kodu nedir?
# 24. Sets: Bir kümenin boş olup olmadığını kontrol eden Python kodunu yazın.
# 25. Number: İki sayının farkını bulan Python ifadesi nedir?
# 26. String: Bir metnin uzunluğunu bulan Python kodu nedir?
# 27. List: Bir listedeki en büyük elemanı bulan Python kodunu yazın.
# 28. Tuple: İki demeti çarpan Python ifadesi nedir?
# 29. Dictionary: Bir sözlüğe yeni bir anahtar ve değer ekleyen Python kodu nedir?
# 30. Sets: İki kümenin simetrik farkını bulan Python kodunu yazın.
# 31. Number: İki sayının çarpımını bulan Python ifadesi nedir?
# 32. String: Bir metnin başındaki ve sonundaki boşlukları kaldıran Python kodu nedir?
# 33. List: Bir listenin elemanlarını küçükten büyüğe sıralayan Python kodunu yazın.
# 34. Tuple: Bir demetin belirli bir aralıktaki elemanlarını bulan Python kodu nedir?
# 35. Dictionary: Bir sözlükten belirli bir anahtarı bulup karşılık gelen değeri getiren Python kodu nedir?
# 36. Sets: İki kümenin alt kümesi olup olmadığını kontrol eden Python kodunu yazın.
# 37. Number: İki sayının bölümünü bulan Python ifadesi nedir?
# 38. String: Bir metni belirli bir karaktere göre bölen Python kodu nedir?
# 39. List: Bir listedeki belirli bir indeksteki elemanı değiştiren Python kodunu yazın.
# 40. Tuple: Bir demette belirli bir değeri bulan Python kodu nedir?
# 41. Dictionary: Bir sözlükteki tüm değerleri listeleyen Python kodu nedir?
# 42. Sets: İki kümenin eşit olup olmadığını kontrol eden Python kodunu yazın.
# 43. Number: Bir sayıyı belirli bir sayıya bölüp kalanı bulan Python ifadesi nedir?
# 44. String: Bir metindeki tüm karakterleri büyük harfe çeviren Python kodu nedir?
# 45. List: Bir listeye başka bir listenin elemanlarını ekleyen Python kodunu yazın.
# 46. Tuple: Bir demeti belirli bir değere göre sıralayan Python kodu nedir?
# 47. Dictionary: Bir sözlükteki tüm anahtar-değer çiftlerini listeleyen Python kodu nedir?
# 48. Sets: İki kümenin birbirine alt küme olup olmadığını kontrol eden Python kodunu yazın.
# 49. Number: Bir sayının mutlak değerini bulan Python ifadesi nedir?
# 50. String: Bir metni belirli bir karaktere göre düzenleyen Python kodunu yazın.
# 51. List: Bir listedeki belirli bir elemanın indeksini tümüyle bulan Python kodu nedir?
# 52. Tuple: İki demeti belirli bir değere göre birleştiren Python kodu nedir?
# 53. Dictionary: Bir sözlükte belirli bir anahtarı kontrol edip varsa karşılık gelen değeri, yoksa belirli bir değeri döndüren Python kodu nedir?
# 54. Sets: İki kümenin aynı elemanlara sahip olup olmadığını kontrol eden Python kodunu yazın.
# 55. Number: İki sayının kuvvetini bulan Python ifadesi nedir?
# 56. String: Bir metni belirli bir karaktere göre parçalayan Python kodunu yazın.
# 57. List: Bir listedeki belirli bir elemanın indeksini bulan ve ilk bulduğu indeksi döndüren Python kodu nedir?
# 58. Tuple: İki demeti belirli bir değere göre filtreleyen Python kodu nedir?
# 59. Dictionary: Bir sözlükte belirli bir anahtarın değerini kontrol eden Python kodu nedir?
